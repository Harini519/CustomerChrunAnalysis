# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.head(10)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
# 5  9305-CDSKC  Female              0      No         No       8          Yes
# 6  1452-KIOVK    Male              0      No        Yes      22          Yes
# 7  6713-OKOMC  Female              0      No         No      10           No
# 8  7892-POOKP  Female              0     Yes         No      28          Yes
# 9  6388-TABGU    Male              0      No        Yes      62          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# ...

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df["TotalCharges"]=pd.to_numeric(df["TotalCharges"],errors="coerce")

# %%
for a in df.select_dtypes("object").columns:
  print(df[a].unique())
# Out:
# ['7590-VHVEG' '5575-GNVDE' '3668-QPYBK' ... '4801-JZAZL' '8361-LTMKD'
#  '3186-AJIEK']
# ['Female' 'Male']
# ['Yes' 'No']
# ['No' 'Yes']
# ['No' 'Yes']
# ['No phone service' 'No' 'Yes']
# ['DSL' 'Fiber optic' 'No']
# ['No' 'Yes' 'No internet service']
# ['Yes' 'No' 'No internet service']
# ['No' 'Yes' 'No internet service']
# ['No' 'Yes' 'No internet service']
# ['No' 'Yes' 'No internet service']
# ['No' 'Yes' 'No internet service']
# ['Month-to-month' 'One year' 'Two year']
# ['Yes' 'No']
# ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# ['No' 'Yes']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
duplicate=df.duplicated()
print(duplicate.sum())
df[duplicate]
# Out:
# 0
# Empty DataFrame
# Columns: [customerID, gender, SeniorCitizen, Partner, Dependents, tenure, PhoneService, MultipleLines, InternetService, OnlineSecurity, OnlineBackup, DeviceProtection, TechSupport, StreamingTV, StreamingMovies, Contract, PaperlessBilling, PaymentMethod, MonthlyCharges, TotalCharges, Churn]
# Index: []
#
# [0 rows x 21 columns]

# %%
###Loooping through the columns to get unique values per columns
for i in df.columns:
    print(f"Unique {i}'s count:{df[i].nunique()}")
    print(f"{df[i].unique()}\n")
# Out:
# Unique customerID's count:7043
# ['7590-VHVEG' '5575-GNVDE' '3668-QPYBK' ... '4801-JZAZL' '8361-LTMKD'
#  '3186-AJIEK']
#
# Unique gender's count:2
# ['Female' 'Male']
#
# Unique SeniorCitizen's count:2
# [0 1]
#
# Unique Partner's count:2
# ['Yes' 'No']
#
# Unique Dependents's count:2
# ['No' 'Yes']
#
# Unique tenure's count:73
# [ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26  0
#  39]
#
# Unique PhoneService's count:2
# ['No' 'Yes']
#
# Unique MultipleLines's count:3
# ['No phone service' 'No' 'Yes']
#
# Unique InternetService's count:3
# ['DSL' 'Fiber optic' 'No']
#
# Unique OnlineSecurity's count:3
# ['No' 'Yes' 'No internet service']
#
# Unique OnlineBackup's count:3
# ['Yes' 'No' 'No internet service']
#
# Unique DeviceProtection's count:3
# ['No' 'Yes' 'No internet service']
#
# ...

# %%
df.groupby('gender')['MonthlyCharges'].agg(['max','median','mean']).plot(kind='bar',figsize=(26,6))
plt.title('Monthly Charges comparison')
# Out:
# Text(0.5, 1.0, 'Monthly Charges comparison')

# %%
plt.figure(figsize=(26,6))
ax = sns.countplot(data=df, x ='gender',hue = 'Churn',palette=['pink', 'skyblue'])
ax.tick_params(axis='x', rotation=45)
plt.title('Gender distribution of Churn')
plt.show()

# %%
df.groupby('gender')['TotalCharges'].agg(['max','median','mean']).plot(kind='bar',figsize=(26,6))
plt.title('Total Charges comarison')
# Out:
# Text(0.5, 1.0, 'Total Charges comarison')

# %%
plt.figure(figsize=(26,6))
ax = sns.histplot(data=df, x ='SeniorCitizen',hue = 'Churn',legend=True,palette=['red', 'cyan'])
ax.tick_params(axis='x', rotation=45)
plt.title('Senior Citizens vs Churn')
plt.show()

# %%
plt.figure(figsize=(26,6))
ax = sns.histplot(data=df, x ='Partner',hue = 'Churn',legend=True,palette=['yellow', 'green'])
ax.tick_params(axis='x', rotation=45)
plt.title('Partner vs Churn')
plt.show()

# %%
plt.figure(figsize=(26,6))
ax = sns.histplot(data=df, x ='tenure',hue = 'Churn',legend=True,palette=['red', 'cyan'])
ax.tick_params(axis='x', rotation=45)
plt.title('Tenure Negative Effect on Churn')
plt.show()

# %%
plt.figure(figsize=(26,6))
ax = sns.histplot(data=df, x ='PhoneService',hue = 'Churn',legend=False,palette=['red', 'cyan'])
ax.tick_params(axis='x', rotation=45)
plt.title('PhoneService vs Churn')
plt.show()

# %%
plt.figure(figsize=(26,6))
ax = sns.countplot(data=df, x ='MultipleLines',hue = 'Churn',palette=['cyan','blue'])
ax.tick_params(axis='x', rotation=45)
plt.title('MultipleLines vs Churn')
plt.show()

# %%
plt.figure(figsize=(26,6))
ax = sns.boxplot(data=df, x ='MonthlyCharges',y = 'Churn',palette=['green','blue'])
ax.tick_params(axis='x', rotation=45)
plt.title('')
plt.show()

# %%
plt.figure(figsize=(26,6))
ax = sns.histplot(data=df, x ='InternetService',hue = 'Churn',legend=True,palette=['pink','red'])
ax.tick_params(axis='x', rotation=45)
plt.title('InternetService vs Churn')
plt.show()

# %%
plt.figure(figsize=(26,6))
sns.histplot(data=df,x ='MonthlyCharges')

plt.figure(figsize=(26,6))
sns.histplot(data=df,x ='TotalCharges')

# %%
sns.heatmap(df.corr())

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data= pd.read_csv("WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %%
data.shape
# Out:
# (7043, 6)

# %%
data.head(10)
# Out:
#    Monthly Charge  Total Charges  Total Refunds  Total Extra Data Charges  \
# 0           65.60         593.30           0.00                         0
# 1           -4.00         542.40          38.33                        10
# 2           73.90         280.85           0.00                         0
# 3           98.00        1237.85           0.00                         0
# 4           83.90         267.40           0.00                         0
# 5           69.40         571.45           0.00                         0
# 6          109.70        7904.25           0.00                         0
# 7           84.65        5377.80           0.00                        20
# 8           48.20         340.35           0.00                         0
# 9           90.45        5957.90           0.00                         0
#
#    Total Long Distance Charges  Total Revenue
# 0                       381.51         974.81
# 1                        96.21         610.28
# ...

# %%
data.dtypes
# Out:
# Monthly Charge                 float64
# Total Charges                  float64
# Total Refunds                  float64
# Total Extra Data Charges         int64
# Total Long Distance Charges    float64
# Total Revenue                  float64
# dtype: object

# %%
data.columns
# Out:
# Index(['Monthly Charge', 'Total Charges', 'Total Refunds',
#        'Total Extra Data Charges', 'Total Long Distance Charges',
#        'Total Revenue'],
#       dtype='object')

# %%
data.describe()
# Out:
#        Monthly Charge  Total Charges  Total Refunds  Total Extra Data Charges  \
# count     7043.000000    7043.000000    7043.000000               7043.000000
# mean        63.596131    2280.381264       1.962182                  6.860713
# std         31.204743    2266.220462       7.902614                 25.104978
# min        -10.000000      18.800000       0.000000                  0.000000
# 25%         30.400000     400.150000       0.000000                  0.000000
# 50%         70.050000    1394.550000       0.000000                  0.000000
# 75%         89.750000    3786.600000       0.000000                  0.000000
# max        118.750000    8684.800000      49.790000                150.000000
#
#        Total Long Distance Charges  Total Revenue
# count                  7043.000000    7043.000000
# mean                    749.099262    3034.379056
# std                     846.660055    2865.204542
# min                       0.000000      21.360000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 6 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Monthly Charge               7043 non-null   float64
#  1   Total Charges                7043 non-null   float64
#  2   Total Refunds                7043 non-null   float64
#  3   Total Extra Data Charges     7043 non-null   int64
#  4   Total Long Distance Charges  7043 non-null   float64
#  5   Total Revenue                7043 non-null   float64
# dtypes: float64(5), int64(1)
# memory usage: 330.3 KB

# %%
for a in data.select_dtypes("object").columns:
  print(data[a].unique())

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 6 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Monthly Charge               7043 non-null   float64
#  1   Total Charges                7043 non-null   float64
#  2   Total Refunds                7043 non-null   float64
#  3   Total Extra Data Charges     7043 non-null   int64
#  4   Total Long Distance Charges  7043 non-null   float64
#  5   Total Revenue                7043 non-null   float64
# dtypes: float64(5), int64(1)
# memory usage: 330.3 KB

# %%
duplicate=data.duplicated()
print(duplicate.sum())
data[duplicate]
# Out:
# 8
#       Monthly Charge  Total Charges  Total Refunds  Total Extra Data Charges  \
# 2944           25.25          25.25            0.0                         0
# 4282           25.10          25.10            0.0                         0
# 5233           24.40          24.40            0.0                         0
# 5336           25.15          25.15            0.0                         0
# 5579           35.90          35.90            0.0                         0
# 5631           24.80          24.80            0.0                         0
# 5874           25.20          25.20            0.0                         0
# 6980           25.05          25.05            0.0                         0
#
#       Total Long Distance Charges  Total Revenue
# 2944                          0.0          25.25
# 4282                          0.0          25.10
# 5233                          0.0          24.40
# 5336                          0.0          25.15
# ...

# %%
data.head()
# Out:
#    Monthly Charge  Total Charges  Total Refunds  Total Extra Data Charges  \
# 0            65.6         593.30           0.00                         0
# 1            -4.0         542.40          38.33                        10
# 2            73.9         280.85           0.00                         0
# 3            98.0        1237.85           0.00                         0
# 4            83.9         267.40           0.00                         0
#
#    Total Long Distance Charges  Total Revenue
# 0                       381.51         974.81
# 1                        96.21         610.28
# 2                       134.60         415.45
# 3                       361.66        1599.51
# 4                        22.14         289.54

# %%
x=data.iloc[:,0:5]
y=data.iloc[:,5]

# %%
from sklearn.model_selection import train_test_split as tts

# %%
xtrain,xtest,ytrain,ytest=tts(x,y,test_size=0.2)

# %%
xtest
# Out:
#       Monthly Charge  Total Charges  Total Refunds  Total Extra Data Charges  \
# 6401           26.30        1763.55           0.00                         0
# 3443           34.55         362.60           0.00                         0
# 4849          105.00        7297.75           0.00                         0
# 100            19.95          58.00           0.00                         0
# 2671           75.55        4707.85           0.00                         0
# ...              ...            ...            ...                       ...
# 658            20.30        1296.15           0.00                         0
# 2185           19.55         294.50           0.00                         0
# 878            19.70         599.25          49.79                         0
# 5597           19.90          19.90           0.00                         0
# 5191           19.15          19.15           0.00                         0
#
#       Total Long Distance Charges
# ...

# %%
ytest
# Out:
# 6401    3287.07
# 3443     362.60
# 4849    8849.56
# 100       66.07
# 2671    5106.64
#          ...
# 658     1445.57
# 2185     560.92
# 878      934.96
# 5597      22.28
# 5191      41.52
# Name: Total Revenue, Length: 1409, dtype: float64

# %%
xtrain
# Out:
#       Monthly Charge  Total Charges  Total Refunds  Total Extra Data Charges  \
# 1944           19.45         921.30            0.0                         0
# 1028           93.25        4631.70            0.0                         0
# 459            93.50        2970.80            0.0                         0
# 2123           81.25        4620.40            0.0                         0
# 2122           34.80         113.95            0.0                         0
# ...              ...            ...            ...                       ...
# 2935           70.35        4124.65            0.0                         0
# 1063          106.40        3211.90            0.0                        60
# 4809          103.20        5744.35            0.0                         0
# 6619          110.50        7069.25            0.0                        60
# 5161           69.65          69.65            0.0                         0
#
#       Total Long Distance Charges
# ...

# %%
ytrain
# Out:
# 1944    3157.66
# 1028    5219.30
# 459     4364.08
# 2123    6070.80
# 2122     113.95
#          ...
# 2935    6860.65
# 1063    4546.60
# 4809    6311.63
# 6619    7492.77
# 5161      98.35
# Name: Total Revenue, Length: 5634, dtype: float64

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dtr=DecisionTreeRegressor()

# %%
dtr.fit(xtrain,ytrain)
# Out:
# DecisionTreeRegressor()

# %%
dtr.score(xtrain,ytrain)
# Out:
# 1.0

# %%
dtr.score(xtest,ytest)
# Out:
# 0.9991673455610366

# %%
ypred=dtr.predict(xtest)

# %%
from sklearn.metrics import r2_score as r
from sklearn.metrics import mean_absolute_error as mae
from sklearn.metrics import mean_squared_error as mse

# %%
mae(ytest,ypred)
# Out:
# 52.057700496806255

# %%
mse(ytest,ypred)
# Out:
# 7018.081347764377

# %%
r(ytest,ypred)
# Out:
# 0.9991673455610366

# %%
mse(ytest,ypred,squared=False)
# Out:
# 83.77398968513066

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data= pd.read_csv("WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %%
data.shape
# Out:
# (7043, 6)

# %%
data.head(5)
# Out:
#    Monthly Charge  Total Charges  Total Refunds  Total Extra Data Charges  \
# 0            65.6         593.30           0.00                         0
# 1            -4.0         542.40          38.33                        10
# 2            73.9         280.85           0.00                         0
# 3            98.0        1237.85           0.00                         0
# 4            83.9         267.40           0.00                         0
#
#    Total Long Distance Charges  Total Revenue
# 0                       381.51         974.81
# 1                        96.21         610.28
# 2                       134.60         415.45
# 3                       361.66        1599.51
# 4                        22.14         289.54

# %%
data.dtypes
# Out:
# Monthly Charge                 float64
# Total Charges                  float64
# Total Refunds                  float64
# Total Extra Data Charges         int64
# Total Long Distance Charges    float64
# Total Revenue                  float64
# dtype: object

# %%
data.columns
# Out:
# Index(['Monthly Charge', 'Total Charges', 'Total Refunds',
#        'Total Extra Data Charges', 'Total Long Distance Charges',
#        'Total Revenue'],
#       dtype='object')

# %%
data.describe()
# Out:
#        Monthly Charge  Total Charges  Total Refunds  Total Extra Data Charges  \
# count     7043.000000    7043.000000    7043.000000               7043.000000
# mean        63.596131    2280.381264       1.962182                  6.860713
# std         31.204743    2266.220462       7.902614                 25.104978
# min        -10.000000      18.800000       0.000000                  0.000000
# 25%         30.400000     400.150000       0.000000                  0.000000
# 50%         70.050000    1394.550000       0.000000                  0.000000
# 75%         89.750000    3786.600000       0.000000                  0.000000
# max        118.750000    8684.800000      49.790000                150.000000
#
#        Total Long Distance Charges  Total Revenue
# count                  7043.000000    7043.000000
# mean                    749.099262    3034.379056
# std                     846.660055    2865.204542
# min                       0.000000      21.360000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 6 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Monthly Charge               7043 non-null   float64
#  1   Total Charges                7043 non-null   float64
#  2   Total Refunds                7043 non-null   float64
#  3   Total Extra Data Charges     7043 non-null   int64
#  4   Total Long Distance Charges  7043 non-null   float64
#  5   Total Revenue                7043 non-null   float64
# dtypes: float64(5), int64(1)
# memory usage: 330.3 KB

# %%
for a in data.select_dtypes("object").columns:
  print(data[a].unique())

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 6 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Monthly Charge               7043 non-null   float64
#  1   Total Charges                7043 non-null   float64
#  2   Total Refunds                7043 non-null   float64
#  3   Total Extra Data Charges     7043 non-null   int64
#  4   Total Long Distance Charges  7043 non-null   float64
#  5   Total Revenue                7043 non-null   float64
# dtypes: float64(5), int64(1)
# memory usage: 330.3 KB

# %%
duplicate=data.duplicated()
print(duplicate.sum())
data[duplicate]
# Out:
# 8
#       Monthly Charge  Total Charges  Total Refunds  Total Extra Data Charges  \
# 2944           25.25          25.25            0.0                         0
# 4282           25.10          25.10            0.0                         0
# 5233           24.40          24.40            0.0                         0
# 5336           25.15          25.15            0.0                         0
# 5579           35.90          35.90            0.0                         0
# 5631           24.80          24.80            0.0                         0
# 5874           25.20          25.20            0.0                         0
# 6980           25.05          25.05            0.0                         0
#
#       Total Long Distance Charges  Total Revenue
# 2944                          0.0          25.25
# 4282                          0.0          25.10
# 5233                          0.0          24.40
# 5336                          0.0          25.15
# ...

# %%
data.head()
# Out:
#    Monthly Charge  Total Charges  Total Refunds  Total Extra Data Charges  \
# 0            65.6         593.30           0.00                         0
# 1            -4.0         542.40          38.33                        10
# 2            73.9         280.85           0.00                         0
# 3            98.0        1237.85           0.00                         0
# 4            83.9         267.40           0.00                         0
#
#    Total Long Distance Charges  Total Revenue
# 0                       381.51         974.81
# 1                        96.21         610.28
# 2                       134.60         415.45
# 3                       361.66        1599.51
# 4                        22.14         289.54

# %%
x=data.iloc[:,0:5]
y=data.iloc[:,5]

# %%
from sklearn.model_selection import train_test_split as tts

# %%
xtrain,xtest,ytrain,ytest=tts(x,y,test_size=0.2)

# %%
xtest
# Out:
#       Monthly Charge  Total Charges  Total Refunds  Total Extra Data Charges  \
# 278            83.85        2674.15          11.37                         0
# 317           104.85        6312.90           0.00                         0
# 1294           25.25        1841.20           0.00                         0
# 2562          101.25        1457.25           0.00                         0
# 5832           43.75         903.60           0.00                         0
# ...              ...            ...            ...                       ...
# 2165          107.65        7082.85           0.00                         0
# 1571           58.00        1734.50           0.00                         0
# 2419           89.75         552.65           0.00                        60
# 429            20.20         558.80           0.00                         0
# 2081           90.85        6470.10           0.00                         0
#
#       Total Long Distance Charges
# ...

# %%
ytest
# Out:
# 278     3035.71
# 317     7722.78
# 1294    5405.92
# 2562    1709.55
# 5832     903.60
#          ...
# 2165    8882.70
# 1571    2153.84
# 2419     819.17
# 429     1557.56
# 2081    9165.10
# Name: Total Revenue, Length: 1409, dtype: float64

# %%
xtrain
# Out:
#       Monthly Charge  Total Charges  Total Refunds  Total Extra Data Charges  \
# 2340           99.50        5890.00            0.0                         0
# 6649           19.05         990.45            0.0                         0
# 6098          100.05        4871.05            0.0                         0
# 4787           94.90        4615.25            0.0                         0
# 1292           50.05        2743.45            0.0                         0
# ...              ...            ...            ...                       ...
# 258            62.05        2511.55            0.0                         0
# 2547           95.60         644.35            0.0                         0
# 1697           73.65        1642.75            0.0                         0
# 877            20.00         860.85            0.0                         0
# 2575           19.45          19.45            0.0                         0
#
#       Total Long Distance Charges
# ...

# %%
ytrain
# Out:
# 2340    7321.93
# 6649    3441.17
# 6098    5292.64
# 4787    6507.00
# 1292    2743.45
#          ...
# 258     2511.55
# 2547     797.72
# 1697    1976.94
# 877     2482.69
# 2575      35.89
# Name: Total Revenue, Length: 5634, dtype: float64

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf=RandomForestRegressor(n_estimators=20)

# %%
rf.fit(xtrain,ytrain)
# Out:
# RandomForestRegressor(n_estimators=20)

# %%
rf.score(xtrain,ytrain)
# Out:
# 0.9999541073859411

# %%
rf.score(xtest,ytest)
# Out:
# 0.9996631632027908

# %%
ypred1=rf.predict(xtest)

# %%
r(ytest,ypred1)
# Out:
# 0.9996631632027908

# %%
mae(ytest,ypred1)
# Out:
# 29.875739176721062

# %%
mse(ytest,ypred1)
# Out:
# 2804.332015064759

# %%
mse(ytest,ypred,squared=False)
# Out:
# 4090.4804817058516

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data= pd.read_csv("WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %%
data.shape
# Out:
# (7043, 6)

# %%
data.head(10)
# Out:
#    Monthly Charge  Total Charges  Total Refunds  Total Extra Data Charges  \
# 0           65.60         593.30           0.00                         0
# 1           -4.00         542.40          38.33                        10
# 2           73.90         280.85           0.00                         0
# 3           98.00        1237.85           0.00                         0
# 4           83.90         267.40           0.00                         0
# 5           69.40         571.45           0.00                         0
# 6          109.70        7904.25           0.00                         0
# 7           84.65        5377.80           0.00                        20
# 8           48.20         340.35           0.00                         0
# 9           90.45        5957.90           0.00                         0
#
#    Total Long Distance Charges  Total Revenue
# 0                       381.51         974.81
# 1                        96.21         610.28
# ...

# %%
data.dtypes
# Out:
# Monthly Charge                 float64
# Total Charges                  float64
# Total Refunds                  float64
# Total Extra Data Charges         int64
# Total Long Distance Charges    float64
# Total Revenue                  float64
# dtype: object

# %%
data.columns
# Out:
# Index(['Monthly Charge', 'Total Charges', 'Total Refunds',
#        'Total Extra Data Charges', 'Total Long Distance Charges',
#        'Total Revenue'],
#       dtype='object')

# %%
data.describe()
# Out:
#        Monthly Charge  Total Charges  Total Refunds  Total Extra Data Charges  \
# count     7043.000000    7043.000000    7043.000000               7043.000000
# mean        63.596131    2280.381264       1.962182                  6.860713
# std         31.204743    2266.220462       7.902614                 25.104978
# min        -10.000000      18.800000       0.000000                  0.000000
# 25%         30.400000     400.150000       0.000000                  0.000000
# 50%         70.050000    1394.550000       0.000000                  0.000000
# 75%         89.750000    3786.600000       0.000000                  0.000000
# max        118.750000    8684.800000      49.790000                150.000000
#
#        Total Long Distance Charges  Total Revenue
# count                  7043.000000    7043.000000
# mean                    749.099262    3034.379056
# std                     846.660055    2865.204542
# min                       0.000000      21.360000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 6 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Monthly Charge               7043 non-null   float64
#  1   Total Charges                7043 non-null   float64
#  2   Total Refunds                7043 non-null   float64
#  3   Total Extra Data Charges     7043 non-null   int64
#  4   Total Long Distance Charges  7043 non-null   float64
#  5   Total Revenue                7043 non-null   float64
# dtypes: float64(5), int64(1)
# memory usage: 330.3 KB

# %%
for a in data.select_dtypes("object").columns:
  print(data[a].unique())

# %%
data.head()
# Out:
#    Monthly Charge  Total Charges  Total Refunds  Total Extra Data Charges  \
# 0            65.6         593.30           0.00                         0
# 1            -4.0         542.40          38.33                        10
# 2            73.9         280.85           0.00                         0
# 3            98.0        1237.85           0.00                         0
# 4            83.9         267.40           0.00                         0
#
#    Total Long Distance Charges  Total Revenue
# 0                       381.51         974.81
# 1                        96.21         610.28
# 2                       134.60         415.45
# 3                       361.66        1599.51
# 4                        22.14         289.54

# %%
x=data.iloc[:,0:5]
y=data.iloc[:,5]

# %%
from sklearn.model_selection import train_test_split as tts

# %%
xtrain,xtest,ytrain,ytest=tts(x,y,test_size=0.3)

# %%
xtest
# Out:
#       Monthly Charge  Total Charges  Total Refunds  Total Extra Data Charges  \
# 1908           39.10         971.30           0.00                         0
# 4679          109.55        5124.55           0.00                         0
# 1900           74.70         165.40           0.00                         0
# 4493           73.80         704.30           0.00                        50
# 4634           79.00        2576.80           0.00                         0
# ...              ...            ...            ...                       ...
# 6038           77.50        1625.00          18.39                        80
# 5415           78.95        2839.65           0.00                         0
# 1886           80.55         184.10           0.00                         0
# 5808           93.70        4154.80           0.00                         0
# 6377          107.45        5680.90          14.76                         0
#
#       Total Long Distance Charges
# ...

# %%
ytest
# Out:
# 1908     971.30
# 4679    5482.69
# 1900     178.42
# 4493     770.95
# 4634    3158.59
#          ...
# 6038    2055.58
# 5415    4226.78
# 1886     251.88
# 5808    4880.68
# 6377    6050.68
# Name: Total Revenue, Length: 2113, dtype: float64

# %%
xtrain
# Out:
#       Monthly Charge  Total Charges  Total Refunds  Total Extra Data Charges  \
# 108            74.75        2111.30            0.0                         0
# 5089           79.40        4238.45            0.0                         0
# 5658          103.10        4889.30            0.0                         0
# 6891           75.30          75.30            0.0                         0
# 5920           26.40         314.95            0.0                         0
# ...              ...            ...            ...                       ...
# 6020           59.80        3246.45            0.0                         0
# 3019           54.85         370.40            0.0                         0
# 5745           74.35         265.35            0.0                         0
# 6426          108.55        5610.70            0.0                         0
# 4110           83.85        2716.30            0.0                         0
#
#       Total Long Distance Charges
# ...

# %%
ytrain
# Out:
# 108     3269.60
# 5089    4978.20
# 5658    5671.38
# 6891     114.74
# 5920     856.75
#          ...
# 6020    4489.53
# 3019     409.67
# 5745     456.63
# 6426    7082.20
# 4110    3987.79
# Name: Total Revenue, Length: 4930, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
ypred2=lr.predict(xtest)

# %%
r(ytest,ypred2)
# Out:
# 1.0

# %%
mae(ytest,ypred2)
# Out:
# 2.054672360106283e-12

# %%
mse(ytest,ypred2)
# Out:
# 6.323430669259616e-24
